# %%
import plotly.express as px 
import plotly.graph_objects as go
from plotly.data import gapminder

# %%
country_stats = gapminder()

# %%
country_stats.describe()
# Out:
#              year      lifeExp           pop      gdpPercap      iso_num
# count  1704.00000  1704.000000  1.704000e+03    1704.000000  1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081   425.880282
# std      17.26533    12.917107  1.061579e+08    9857.454543   248.305709
# min    1952.00000    23.599000  6.001100e+04     241.165876     4.000000
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309   208.000000
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989   410.000000
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346   638.000000
# max    2007.00000    82.603000  1.318683e+09  113523.132900   894.000000

# %%
country_stats
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
country_stats["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
px.line(country_stats, x="year", y="lifeExp", color="country")
# Out:
# <div>                            <div id="b3548d21-21ef-4592-9827-2c2b7f9bb97c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3548d21-21ef-4592-9827-2c2b7f9bb97c")) {                    Plotly.newPlot(                        "b3548d21-21ef-4592-9827-2c2b7f9bb97c",                        [{"hovertemplate":"country=Afghanistan<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x","y":[28.801,30.332,31.997,34.02,36.088,38.438,39.854,40.822,41.674,41.76300000000001,42.129,43.828],"yaxis":"y","type":"scattergl"},{"hovertemplate":"cou
# ...

# %%
population_per_country = country_stats.groupby(["year", "continent"])["pop"].sum().reset_index()
population_per_country
fig = px.bar(country_stats, x="continent", y="pop", color="country", animation_frame="year", range_y=[0, 3_500_000_000])
fig
# Out:
# <div>                            <div id="fee2ed82-b214-430a-a901-a608114a4a0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fee2ed82-b214-430a-a901-a608114a4a0d")) {                    Plotly.newPlot(                        "fee2ed82-b214-430a-a901-a608114a4a0d",                        [{"alignmentgroup":"True","hovertemplate":"country=Afghanistan<br>year=1952<br>continent=%{x}<br>pop=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia"],"xaxis":"x","y":[8425333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"country=Albania<br>year=1952<br>continent=%{x}<br>po
# ...

# %%
fig = px.density_heatmap(country_stats, x="lifeExp", y="gdpPercap")
fig
# Out:
# <div>                            <div id="81ea62b8-741f-4f37-b889-a6d74830fd33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81ea62b8-741f-4f37-b889-a6d74830fd33")) {                    Plotly.newPlot(                        "81ea62b8-741f-4f37-b889-a6d74830fd33",                        [{"coloraxis":"coloraxis","hovertemplate":"lifeExp=%{x}<br>gdpPercap=%{y}<br>count=%{z}<extra></extra>","name":"","x":[28.801,30.332,31.997,34.02,36.088,38.438,39.854,40.822,41.674,41.76300000000001,42.129,43.828,55.23,59.28,64.82,66.22,67.69,68.93,70.42,72.0,71.581,72.95,75.65100000000002,76.423,43.077,45.685,48.303,51.407,54.518,58.014,61.368,65.79899999999999,67.744,69.152,70.994,72.301,30.015,31.999,34.0,35.985,37.928,39.483,39.942,39.906,40.647,40.963,41.003,
# ...

# %%
fig = px.line(country_stats, x="year", y="lifeExp", color="country", facet_row="continent")
fig
# Out:
# <div>                            <div id="3c5b350f-3631-4424-9392-88f1bc404e7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c5b350f-3631-4424-9392-88f1bc404e7a")) {                    Plotly.newPlot(                        "3c5b350f-3631-4424-9392-88f1bc404e7a",                        [{"hovertemplate":"country=Afghanistan<br>continent=Asia<br>year=%{x}<br>lifeExp=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":[1952,1957,1962,1967,1972,1977,1982,1987,1992,1997,2002,2007],"xaxis":"x5","y":[28.801,30.332,31.997,34.02,36.088,38.438,39.854,40.822,41.674,41.76300000000001,42.129,43.828],"yaxis":"y5","type":"scattergl"},{
# ...
